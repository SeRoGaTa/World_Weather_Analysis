# %%
# Import the dependencies.
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the dependencies.
import requests
from datetime import datetime
from config import w_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.000, 90.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 766

# %%
# Openweather url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + w_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | codrington
# Processing Record 2 of Set 1 | itaquitinga
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | kamenka
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | hobyo
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | narsaq
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | polis
# Processing Record 16 of Set 1 | muros
# Processing Record 17 of Set 1 | petrokamenskoye
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | bilma
# Processing Record 20 of Set 1 | lubao
# Processing Record 21 of Set 1 | senno
# Processing Record 22 of Set 1 | mahibadhoo
# Processing Record 23 of Set 1 | cayenne
# Processing Record 24 of Set 1 | huarmey
# Processing Record 25 of Set 1 | codajas
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | sakakah
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | ponta delgada
# Processing Record 34 of Set 1 | quito
# Processing Record 35 of Set 1 | sarakhs
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | najran
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | ostrovnoy
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | abatskoye
# Processing Record 43 of Set 1 | takoradi
# Processing Record 44 of Set 1 | port-cartier
# Processing Record 45 of Set 1 | sambava
# Processing Record 46 of Set 1 | krasnoselkup
# Processing Record 47 of Set 1 | nouadhibou
# Processing Record 48 of Set 1 | atasu
# Processing Record 49 of Set 1 | nanortalik
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | shimsk
# Processing Record 2 of Set 2 | caceres
# Processing Record 3 of Set 2 | yumaguzino
# Processing Record 4 of Set 2 | lloret de mar
# Processing Record 5 of Set 2 | floresta
# Processing Record 6 of Set 2 | ahtopol
# Processing Record 7 of Set 2 | killybegs
# Processing Record 8 of Set 2 | porto nacional
# Processing Record 9 of Set 2 | villanueva de cordoba
# Processing Record 10 of Set 2 | laguna
# Processing Record 11 of Set 2 | ubaira
# Processing Record 12 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 13 of Set 2 | safita
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | maniitsoq
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | olafsvik
# Processing Record 21 of Set 2 | semenivka
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | aswan
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | henties bay
# Processing Record 27 of Set 2 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | challapata
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | luderitz
# Processing Record 33 of Set 2 | nouakchott
# Processing Record 34 of Set 2 | hadejia
# Processing Record 35 of Set 2 | mount pleasant
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | inhambane
# Processing Record 38 of Set 2 | riyadh
# Processing Record 39 of Set 2 | kidal
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | les cayes
# Processing Record 42 of Set 2 | maceio
# Processing Record 43 of Set 2 | barmer
# Processing Record 44 of Set 2 | aska
# Processing Record 45 of Set 2 | south burlington
# Processing Record 46 of Set 2 | manturovo
# Processing Record 47 of Set 2 | aksarka
# Processing Record 48 of Set 2 | necochea
# Processing Record 49 of Set 2 | namibe
# Processing Record 50 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 3 | bonthe
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | vardo
# Processing Record 4 of Set 3 | awjilah
# Processing Record 5 of Set 3 | marawi
# Processing Record 6 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 3 | husavik
# Processing Record 8 of Set 3 | kalmunai
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | liverpool
# Processing Record 11 of Set 3 | bakel
# Processing Record 12 of Set 3 | cumana
# Processing Record 13 of Set 3 | abeche
# Processing Record 14 of Set 3 | berkak
# Processing Record 15 of Set 3 | keti bandar
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | ferrol
# Processing Record 18 of Set 3 | kisangani
# Processing Record 19 of Set 3 | islamkot
# Processing Record 20 of Set 3 | kabinda
# Processing Record 21 of Set 3 | peniche
# Processing Record 22 of Set 3 | makinsk
# Processing Record 23 of Set 3 | barsana
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | bodden town
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | vila franca do campo
# Processing Record 28 of Set 3 | eidsvag
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | birkeland
# Processing Record 32 of Set 3 | grand-lahou
# Processing Record 33 of Set 3 | barranca
# Processing Record 34 of Set 3 | foki
# Processing Record 35 of Set 3 | formosa do rio preto
# Processing Record 36 of Set 3 | yambio
# Processing Record 37 of Set 3 | raudeberg
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | arlit
# Processing Record 40 of Set 3 | ilhabela
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | aleppo
# Processing Record 44 of Set 3 | gravdal
# Processing Record 45 of Set 3 | totskoye
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | hearst
# Processing Record 48 of Set 3 | wageningen
# Processing Record 49 of Set 3 | nkowakowa
# Processing Record 50 of Set 3 | sainte-marie
# Processing Record 1 of Set 4 | banda aceh
# Processing Record 2 of Set 4 | soligalich
# Processing Record 3 of Set 4 | saint-pierre
# Processing Record 4 of Set 4 | atbasar
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | richards bay
# Processing Record 7 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 8 of Set 4 | aleksandrovskaya
# Processing Record 9 of Set 4 | rivadavia
# Processing Record 10 of Set 4 | omboue
# Processing Record 11 of Set 4 | filadelfia
# Processing Record 12 of Set 4 | sovetskiy
# Processing Record 13 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 4 | bougouni
# Processing Record 15 of Set 4 | oranjestad
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | ulundi
# Processing Record 18 of Set 4 | jalu
# Processing Record 19 of Set 4 | diffa
# Processing Record 20 of Set 4 | edmundston
# Processing Record 21 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | sioux lookout
# Processing Record 25 of Set 4 | vestmannaeyjar
# Processing Record 26 of Set 4 | marzuq
# Processing Record 27 of Set 4 | zhovtneve
# Processing Record 28 of Set 4 | njeru
# Processing Record 29 of Set 4 | inta
# Processing Record 30 of Set 4 | lisakovsk
# Processing Record 31 of Set 4 | rocha
# Processing Record 32 of Set 4 | santa luzia
# Processing Record 33 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 4 | clyde river
# Processing Record 35 of Set 4 | ondangwa
# Processing Record 36 of Set 4 | mahajanga
# Processing Record 37 of Set 4 | quatre cocos
# Processing Record 38 of Set 4 | kalabo
# Processing Record 39 of Set 4 | kudahuvadhoo
# Processing Record 40 of Set 4 | sao felix do xingu
# Processing Record 41 of Set 4 | klaksvik
# Processing Record 42 of Set 4 | kez
# Processing Record 43 of Set 4 | maldonado
# Processing Record 44 of Set 4 | dudinka
# Processing Record 45 of Set 4 | yauya
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | dikson
# Processing Record 48 of Set 4 | pangnirtung
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | kimparana
# Processing Record 2 of Set 5 | bolanos de calatrava
# Processing Record 3 of Set 5 | porangatu
# Processing Record 4 of Set 5 | warmbad
# Processing Record 5 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 5 | chapais
# Processing Record 7 of Set 5 | constitucion
# Processing Record 8 of Set 5 | santa isabel do rio negro
# Processing Record 9 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 5 | tiznit
# Processing Record 12 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 5 | kuusamo
# Processing Record 14 of Set 5 | moose factory
# Processing Record 15 of Set 5 | camacha
# Processing Record 16 of Set 5 | bud
# Processing Record 17 of Set 5 | santa maria
# Processing Record 18 of Set 5 | goure
# Processing Record 19 of Set 5 | kismayo
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | beisfjord
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | bloemhof
# Processing Record 24 of Set 5 | morondava
# Processing Record 25 of Set 5 | pljevlja
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | velikiy ustyug
# Processing Record 28 of Set 5 | tessalit
# Processing Record 29 of Set 5 | chimbote
# Processing Record 30 of Set 5 | iquitos
# Processing Record 31 of Set 5 | dingle
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | bronnoysund
# Processing Record 34 of Set 5 | sekoma
# Processing Record 35 of Set 5 | lugovoy
# Processing Record 36 of Set 5 | mbekenyera
# Processing Record 37 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 5 | puerto narino
# Processing Record 42 of Set 5 | mosquera
# Processing Record 43 of Set 5 | mulchen
# Processing Record 44 of Set 5 | la palma
# Processing Record 45 of Set 5 | burica
# City not found. Skipping...
# Processing Record 46 of Set 5 | am timan
# Processing Record 47 of Set 5 | kamina
# Processing Record 48 of Set 5 | lukulu
# Processing Record 49 of Set 5 | kaura namoda
# Processing Record 50 of Set 5 | severinia
# Processing Record 1 of Set 6 | ribera
# Processing Record 2 of Set 6 | iisalmi
# Processing Record 3 of Set 6 | ouadda
# Processing Record 4 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 6 | syracuse
# Processing Record 6 of Set 6 | sharan
# Processing Record 7 of Set 6 | fereydun kenar
# Processing Record 8 of Set 6 | tharad
# Processing Record 9 of Set 6 | sundby
# Processing Record 10 of Set 6 | pombia
# Processing Record 11 of Set 6 | loandjili
# Processing Record 12 of Set 6 | castro
# Processing Record 13 of Set 6 | boke
# Processing Record 14 of Set 6 | stornoway
# Processing Record 15 of Set 6 | temyasovo
# Processing Record 16 of Set 6 | praia da vitoria
# Processing Record 17 of Set 6 | jinka
# Processing Record 18 of Set 6 | calais
# Processing Record 19 of Set 6 | wajir
# Processing Record 20 of Set 6 | iracoubo
# Processing Record 21 of Set 6 | collingwood
# Processing Record 22 of Set 6 | kontagora
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | shakawe
# Processing Record 25 of Set 6 | warri
# Processing Record 26 of Set 6 | ugep
# Processing Record 27 of Set 6 | buzmeyin
# Processing Record 28 of Set 6 | udayagiri
# Processing Record 29 of Set 6 | sao filipe
# Processing Record 30 of Set 6 | san-pedro
# Processing Record 31 of Set 6 | colares
# Processing Record 32 of Set 6 | bom jesus da lapa
# Processing Record 33 of Set 6 | joao pinheiro
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | sao jose da coroa grande
# Processing Record 36 of Set 6 | benguela
# Processing Record 37 of Set 6 | mwinilunga
# Processing Record 38 of Set 6 | bereda
# Processing Record 39 of Set 6 | young
# Processing Record 40 of Set 6 | hofn
# Processing Record 41 of Set 6 | halifax
# Processing Record 42 of Set 6 | motala
# Processing Record 43 of Set 6 | darnah
# Processing Record 44 of Set 6 | santa cruz del norte
# Processing Record 45 of Set 6 | santa fe
# Processing Record 46 of Set 6 | hauterive
# Processing Record 47 of Set 6 | sinnamary
# Processing Record 48 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 6 | nisia floresta
# Processing Record 50 of Set 6 | tyukhtet
# Processing Record 1 of Set 7 | nortelandia
# Processing Record 2 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 7 | tchaourou
# Processing Record 4 of Set 7 | karla
# Processing Record 5 of Set 7 | qandala
# Processing Record 6 of Set 7 | cabanas
# Processing Record 7 of Set 7 | imbituba
# Processing Record 8 of Set 7 | eyl
# Processing Record 9 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 10 of Set 7 | kpalime
# Processing Record 11 of Set 7 | lons-le-saunier
# Processing Record 12 of Set 7 | sisimiut
# Processing Record 13 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 7 | kozhva
# Processing Record 15 of Set 7 | sao raimundo das mangabeiras
# Processing Record 16 of Set 7 | jacareacanga
# Processing Record 17 of Set 7 | sorkjosen
# Processing Record 18 of Set 7 | matay
# Processing Record 19 of Set 7 | bayburt
# Processing Record 20 of Set 7 | mehamn
# Processing Record 21 of Set 7 | roald
# Processing Record 22 of Set 7 | zaraza
# Processing Record 23 of Set 7 | luanda
# Processing Record 24 of Set 7 | bayeux
# Processing Record 25 of Set 7 | kushmurun
# Processing Record 26 of Set 7 | bardiyah
# Processing Record 27 of Set 7 | kumylzhenskaya
# Processing Record 28 of Set 7 | borovskoy
# Processing Record 29 of Set 7 | contamana
# Processing Record 30 of Set 7 | ferme-neuve
# Processing Record 31 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 7 | rudnichnyy
# Processing Record 33 of Set 7 | maglaj
# Processing Record 34 of Set 7 | locri
# Processing Record 35 of Set 7 | gornopravdinsk
# Processing Record 36 of Set 7 | san vicente de canete
# Processing Record 37 of Set 7 | general roca
# Processing Record 38 of Set 7 | fort-shevchenko
# Processing Record 39 of Set 7 | rundu
# Processing Record 40 of Set 7 | elizabeth city
# Processing Record 41 of Set 7 | bafra
# Processing Record 42 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 43 of Set 7 | angoche
# Processing Record 44 of Set 7 | nagorsk
# Processing Record 45 of Set 7 | torello
# Processing Record 46 of Set 7 | harindanga
# Processing Record 47 of Set 7 | nizwa
# Processing Record 48 of Set 7 | santo domingo
# Processing Record 49 of Set 7 | holbeach
# Processing Record 50 of Set 7 | inirida
# Processing Record 1 of Set 8 | buta
# Processing Record 2 of Set 8 | helmstedt
# Processing Record 3 of Set 8 | nurota
# Processing Record 4 of Set 8 | axim
# Processing Record 5 of Set 8 | gazalkent
# Processing Record 6 of Set 8 | paracuru
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | nador
# Processing Record 9 of Set 8 | xique-xique
# Processing Record 10 of Set 8 | qasigiannguit
# Processing Record 11 of Set 8 | putyatino
# Processing Record 12 of Set 8 | izhma
# Processing Record 13 of Set 8 | baft
# Processing Record 14 of Set 8 | veisiejai
# Processing Record 15 of Set 8 | hampton
# Processing Record 16 of Set 8 | taltal
# Processing Record 17 of Set 8 | vila do maio
# Processing Record 18 of Set 8 | ritchie
# Processing Record 19 of Set 8 | akropong
# Processing Record 20 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 8 | la asuncion
# Processing Record 22 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | bonavista
# Processing Record 25 of Set 8 | ouallam
# Processing Record 26 of Set 8 | ampanihy
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | goderich
# Processing Record 29 of Set 8 | miraflores
# Processing Record 30 of Set 8 | pizhanka
# Processing Record 31 of Set 8 | nowy dwor mazowiecki
# Processing Record 32 of Set 8 | rio gallegos
# Processing Record 33 of Set 8 | sharjah
# Processing Record 34 of Set 8 | ayolas
# Processing Record 35 of Set 8 | lebu
# Processing Record 36 of Set 8 | tazmalt
# Processing Record 37 of Set 8 | hammerfest
# Processing Record 38 of Set 8 | roxana
# Processing Record 39 of Set 8 | constantine
# Processing Record 40 of Set 8 | louis trichardt
# Processing Record 41 of Set 8 | havre-saint-pierre
# Processing Record 42 of Set 8 | andra
# Processing Record 43 of Set 8 | ashland
# Processing Record 44 of Set 8 | raga
# Processing Record 45 of Set 8 | lodja
# Processing Record 46 of Set 8 | houma
# Processing Record 47 of Set 8 | kusk
# City not found. Skipping...
# Processing Record 48 of Set 8 | sorland
# Processing Record 49 of Set 8 | taua
# Processing Record 50 of Set 8 | saint anthony
# Processing Record 1 of Set 9 | san pedro
# Processing Record 2 of Set 9 | comodoro rivadavia
# Processing Record 3 of Set 9 | waldoboro
# Processing Record 4 of Set 9 | mizdah
# Processing Record 5 of Set 9 | kem
# Processing Record 6 of Set 9 | chemal
# Processing Record 7 of Set 9 | nalut
# Processing Record 8 of Set 9 | lokosovo
# Processing Record 9 of Set 9 | brunswick
# Processing Record 10 of Set 9 | qaracala
# Processing Record 11 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 12 of Set 9 | nordfjordeid
# Processing Record 13 of Set 9 | iranshahr
# Processing Record 14 of Set 9 | umba
# Processing Record 15 of Set 9 | antalaha
# Processing Record 16 of Set 9 | nueva loja
# Processing Record 17 of Set 9 | le moule
# Processing Record 18 of Set 9 | labrea
# Processing Record 19 of Set 9 | taoudenni
# Processing Record 20 of Set 9 | basse
# Processing Record 21 of Set 9 | abnub
# Processing Record 22 of Set 9 | porto walter
# Processing Record 23 of Set 9 | barsovo
# Processing Record 24 of Set 9 | mitsamiouli
# Processing Record 25 of Set 9 | haverfordwest
# Processing Record 26 of Set 9 | zonguldak
# Processing Record 27 of Set 9 | demba
# Processing Record 28 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 9 | montepuez
# Processing Record 30 of Set 9 | bolpur
# Processing Record 31 of Set 9 | belmonte
# Processing Record 32 of Set 9 | honningsvag
# Processing Record 33 of Set 9 | kilindoni
# Processing Record 34 of Set 9 | diamantino
# Processing Record 35 of Set 9 | coquimbo
# Processing Record 36 of Set 9 | vicuna
# Processing Record 37 of Set 9 | yabrud
# Processing Record 38 of Set 9 | barda
# Processing Record 39 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 9 | batticaloa
# Processing Record 41 of Set 9 | bertoua
# Processing Record 42 of Set 9 | mondeville
# Processing Record 43 of Set 9 | iskilip
# Processing Record 44 of Set 9 | tucuman
# Processing Record 45 of Set 9 | salvador
# Processing Record 46 of Set 9 | nassau
# Processing Record 47 of Set 9 | birin
# Processing Record 48 of Set 9 | tuysarkan
# City not found. Skipping...
# Processing Record 49 of Set 9 | pamfila
# Processing Record 50 of Set 9 | srinivaspur
# Processing Record 1 of Set 10 | botevgrad
# Processing Record 2 of Set 10 | samaipata
# Processing Record 3 of Set 10 | usinsk
# Processing Record 4 of Set 10 | los llanos de aridane
# Processing Record 5 of Set 10 | mabaruma
# Processing Record 6 of Set 10 | zaysan
# Processing Record 7 of Set 10 | bondoukou
# Processing Record 8 of Set 10 | tepu
# Processing Record 9 of Set 10 | carlos chagas
# Processing Record 10 of Set 10 | ibotirama
# Processing Record 11 of Set 10 | kosd
# Processing Record 12 of Set 10 | point pleasant
# Processing Record 13 of Set 10 | aquiraz
# Processing Record 14 of Set 10 | sikonge
# Processing Record 15 of Set 10 | malakal
# Processing Record 16 of Set 10 | ajaccio
# Processing Record 17 of Set 10 | eirunepe
# Processing Record 18 of Set 10 | rawson
# Processing Record 19 of Set 10 | ribeira brava
# Processing Record 20 of Set 10 | lusambo
# Processing Record 21 of Set 10 | agdas
# Processing Record 22 of Set 10 | gudiyattam
# City not found. Skipping...
# Processing Record 23 of Set 10 | chimore
# Processing Record 24 of Set 10 | yarkovo
# Processing Record 25 of Set 10 | nicoya
# Processing Record 26 of Set 10 | valpacos
# Processing Record 27 of Set 10 | strezhevoy
# Processing Record 28 of Set 10 | jizan
# Processing Record 29 of Set 10 | bloemfontein
# Processing Record 30 of Set 10 | lasa
# Processing Record 31 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 10 | mayumba
# Processing Record 33 of Set 10 | zaltan
# Processing Record 34 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 10 | boden
# Processing Record 36 of Set 10 | malpe
# Processing Record 37 of Set 10 | carlisle
# Processing Record 38 of Set 10 | harnosand
# Processing Record 39 of Set 10 | urucara
# Processing Record 40 of Set 10 | sao gabriel da cachoeira
# Processing Record 41 of Set 10 | campos
# Processing Record 42 of Set 10 | plyussa
# Processing Record 43 of Set 10 | kirkwall
# Processing Record 44 of Set 10 | emba
# Processing Record 45 of Set 10 | bobosevo
# City not found. Skipping...
# Processing Record 46 of Set 10 | igrim
# Processing Record 47 of Set 10 | qostanay
# Processing Record 48 of Set 10 | pont-rouge
# Processing Record 49 of Set 10 | rakiv lis
# Processing Record 50 of Set 10 | faya
# Processing Record 1 of Set 11 | zharkent
# Processing Record 2 of Set 11 | aligudarz
# Processing Record 3 of Set 11 | zlobin
# Processing Record 4 of Set 11 | guarapari
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | rorvik
# Processing Record 7 of Set 11 | pangody
# Processing Record 8 of Set 11 | mariental
# Processing Record 9 of Set 11 | camacupa
# Processing Record 10 of Set 11 | normandin
# Processing Record 11 of Set 11 | praia
# Processing Record 12 of Set 11 | shelburne
# Processing Record 13 of Set 11 | hetauda
# Processing Record 14 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 11 | kalofer
# Processing Record 16 of Set 11 | vieux fort
# Processing Record 17 of Set 11 | butwal
# Processing Record 18 of Set 11 | matasaru
# Processing Record 19 of Set 11 | gambela
# Processing Record 20 of Set 11 | benghazi
# Processing Record 21 of Set 11 | thunder bay
# Processing Record 22 of Set 11 | pimenteiras
# Processing Record 23 of Set 11 | dehloran
# Processing Record 24 of Set 11 | san jose de ocoa
# Processing Record 25 of Set 11 | tabou
# Processing Record 26 of Set 11 | dahanu
# Processing Record 27 of Set 11 | duz
# City not found. Skipping...
# Processing Record 28 of Set 11 | alta floresta
# Processing Record 29 of Set 11 | dolores
# Processing Record 30 of Set 11 | vestmanna
# Processing Record 31 of Set 11 | kasane
# Processing Record 32 of Set 11 | shumyachi
# Processing Record 33 of Set 11 | abha
# Processing Record 34 of Set 11 | ruwi
# Processing Record 35 of Set 11 | ambovombe
# Processing Record 36 of Set 11 | boddam
# Processing Record 37 of Set 11 | pentecoste
# Processing Record 38 of Set 11 | callaway
# Processing Record 39 of Set 11 | lebowakgomo
# Processing Record 40 of Set 11 | kashi
# Processing Record 41 of Set 11 | acarau
# Processing Record 42 of Set 11 | medvezhyegorsk
# Processing Record 43 of Set 11 | sfantu gheorghe
# Processing Record 44 of Set 11 | potosi
# Processing Record 45 of Set 11 | dwarka
# Processing Record 46 of Set 11 | pankrushikha
# Processing Record 47 of Set 11 | jardim
# Processing Record 48 of Set 11 | sedhiou
# Processing Record 49 of Set 11 | tsumeb
# Processing Record 50 of Set 11 | basoko
# Processing Record 1 of Set 12 | dhidhdhoo
# Processing Record 2 of Set 12 | agirish
# Processing Record 3 of Set 12 | knysna
# Processing Record 4 of Set 12 | santa marta
# Processing Record 5 of Set 12 | bakchar
# Processing Record 6 of Set 12 | mumbwa
# Processing Record 7 of Set 12 | muravlenko
# Processing Record 8 of Set 12 | copiapo
# Processing Record 9 of Set 12 | cotonou
# Processing Record 10 of Set 12 | vidalia
# Processing Record 11 of Set 12 | zhezkazgan
# Processing Record 12 of Set 12 | oistins
# Processing Record 13 of Set 12 | kavarna
# Processing Record 14 of Set 12 | shahr-e babak
# Processing Record 15 of Set 12 | marystown
# Processing Record 16 of Set 12 | bahia honda
# Processing Record 17 of Set 12 | linden
# Processing Record 18 of Set 12 | jupiter
# Processing Record 19 of Set 12 | adre
# Processing Record 20 of Set 12 | suleja
# Processing Record 21 of Set 12 | ornskoldsvik
# Processing Record 22 of Set 12 | ballina
# Processing Record 23 of Set 12 | juba
# Processing Record 24 of Set 12 | viedma
# Processing Record 25 of Set 12 | carmo
# Processing Record 26 of Set 12 | gamba
# Processing Record 27 of Set 12 | ocumare del tuy
# Processing Record 28 of Set 12 | ustka
# Processing Record 29 of Set 12 | bamora
# Processing Record 30 of Set 12 | tazovskiy
# Processing Record 31 of Set 12 | boa vista
# Processing Record 32 of Set 12 | puerto del rosario
# Processing Record 33 of Set 12 | eyemouth
# Processing Record 34 of Set 12 | havelock
# Processing Record 35 of Set 12 | truro
# Processing Record 36 of Set 12 | melbu
# Processing Record 37 of Set 12 | castelo branco
# Processing Record 38 of Set 12 | intipuca
# Processing Record 39 of Set 12 | wattegama
# Processing Record 40 of Set 12 | chabahar
# Processing Record 41 of Set 12 | caravelas
# Processing Record 42 of Set 12 | umm lajj
# Processing Record 43 of Set 12 | vyartsilya
# Processing Record 44 of Set 12 | lichtenburg
# Processing Record 45 of Set 12 | conceicao do araguaia
# Processing Record 46 of Set 12 | agadir
# Processing Record 47 of Set 12 | diego de almagro
# Processing Record 48 of Set 12 | pailon
# Processing Record 49 of Set 12 | harper
# Processing Record 50 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 13 | chlorakas
# Processing Record 2 of Set 13 | toamasina
# Processing Record 3 of Set 13 | kindu
# Processing Record 4 of Set 13 | puerto concordia
# Processing Record 5 of Set 13 | cap malheureux
# Processing Record 6 of Set 13 | maraa
# Processing Record 7 of Set 13 | dakar
# Processing Record 8 of Set 13 | buritizeiro
# Processing Record 9 of Set 13 | emet
# Processing Record 10 of Set 13 | sant pere de ribes
# Processing Record 11 of Set 13 | yacuiba
# Processing Record 12 of Set 13 | novosergiyevka
# Processing Record 13 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 13 | saint-francois
# Processing Record 15 of Set 13 | markala
# Processing Record 16 of Set 13 | talcahuano
# Processing Record 17 of Set 13 | coihaique
# Processing Record 18 of Set 13 | canutama
# Processing Record 19 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 13 | solec kujawski
# Processing Record 21 of Set 13 | mantua
# Processing Record 22 of Set 13 | tukrah
# Processing Record 23 of Set 13 | vitoria
# Processing Record 24 of Set 13 | vacha
# Processing Record 25 of Set 13 | yarada
# Processing Record 26 of Set 13 | bandarbeyla
# Processing Record 27 of Set 13 | staryy nadym
# Processing Record 28 of Set 13 | amapa
# Processing Record 29 of Set 13 | veraval
# Processing Record 30 of Set 13 | polunochnoye
# Processing Record 31 of Set 13 | oranjemund
# Processing Record 32 of Set 13 | abu zabad
# Processing Record 33 of Set 13 | karachi
# Processing Record 34 of Set 13 | coruripe
# Processing Record 35 of Set 13 | chiredzi
# Processing Record 36 of Set 13 | caucaia
# Processing Record 37 of Set 13 | suksun
# Processing Record 38 of Set 13 | quelimane
# Processing Record 39 of Set 13 | dutse
# Processing Record 40 of Set 13 | marsh harbour
# Processing Record 41 of Set 13 | maiduguri
# Processing Record 42 of Set 13 | lucea
# Processing Record 43 of Set 13 | la libertad
# Processing Record 44 of Set 13 | skowhegan
# Processing Record 45 of Set 13 | port hawkesbury
# Processing Record 46 of Set 13 | sur
# Processing Record 47 of Set 13 | novyy urengoy
# Processing Record 48 of Set 13 | morshansk
# Processing Record 49 of Set 13 | kirzhach
# Processing Record 50 of Set 13 | manzil salim
# Processing Record 1 of Set 14 | aberystwyth
# Processing Record 2 of Set 14 | sindor
# Processing Record 3 of Set 14 | olinda
# Processing Record 4 of Set 14 | port-gentil
# Processing Record 5 of Set 14 | wloclawek
# Processing Record 6 of Set 14 | nuuk
# Processing Record 7 of Set 14 | peterhead
# Processing Record 8 of Set 14 | nyagan
# Processing Record 9 of Set 14 | pontal do parana
# Processing Record 10 of Set 14 | nantucket
# Processing Record 11 of Set 14 | hun
# Processing Record 12 of Set 14 | santa rosa
# Processing Record 13 of Set 14 | wum
# Processing Record 14 of Set 14 | mattru
# Processing Record 15 of Set 14 | mazagao
# Processing Record 16 of Set 14 | nidzica
# Processing Record 17 of Set 14 | betera
# Processing Record 18 of Set 14 | surt
# Processing Record 19 of Set 14 | kathmandu
# Processing Record 20 of Set 14 | villavicencio
# Processing Record 21 of Set 14 | sechura
# Processing Record 22 of Set 14 | durres
# Processing Record 23 of Set 14 | waverly
# Processing Record 24 of Set 14 | jevargi
# Processing Record 25 of Set 14 | deer lake
# Processing Record 26 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 27 of Set 14 | kolyvan
# Processing Record 28 of Set 14 | pangoa
# Processing Record 29 of Set 14 | havoysund
# Processing Record 30 of Set 14 | balaka
# Processing Record 31 of Set 14 | ugljevik
# Processing Record 32 of Set 14 | mattawa
# Processing Record 33 of Set 14 | murgab
# Processing Record 34 of Set 14 | salta
# Processing Record 35 of Set 14 | manavalakurichi
# Processing Record 36 of Set 14 | kinrooi
# Processing Record 37 of Set 14 | saint-ambroise
# Processing Record 38 of Set 14 | pedro juan caballero
# Processing Record 39 of Set 14 | great yarmouth
# Processing Record 40 of Set 14 | betafo
# Processing Record 41 of Set 14 | saint marys
# Processing Record 42 of Set 14 | jumilla
# Processing Record 43 of Set 14 | shache
# Processing Record 44 of Set 14 | parfenyevo
# Processing Record 45 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 14 | adrar
# Processing Record 47 of Set 14 | tuskegee
# Processing Record 48 of Set 14 | qaqortoq
# Processing Record 49 of Set 14 | kutum
# Processing Record 50 of Set 14 | borba
# Processing Record 1 of Set 15 | balykshi
# Processing Record 2 of Set 15 | haradok
# Processing Record 3 of Set 15 | inongo
# Processing Record 4 of Set 15 | savannah bight
# Processing Record 5 of Set 15 | garowe
# Processing Record 6 of Set 15 | bermeo
# Processing Record 7 of Set 15 | winneba
# Processing Record 8 of Set 15 | kirtipur
# Processing Record 9 of Set 15 | djenne
# Processing Record 10 of Set 15 | hambantota
# Processing Record 11 of Set 15 | igarka
# Processing Record 12 of Set 15 | vodnyy
# Processing Record 13 of Set 15 | oum hadjer
# Processing Record 14 of Set 15 | saint-joseph
# Processing Record 15 of Set 15 | hwange
# Processing Record 16 of Set 15 | asfi
# Processing Record 17 of Set 15 | abu samrah
# Processing Record 18 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 15 | poretskoye
# Processing Record 20 of Set 15 | turkan
# Processing Record 21 of Set 15 | bom jesus
# Processing Record 22 of Set 15 | stribro
# Processing Record 23 of Set 15 | muzhi
# Processing Record 24 of Set 15 | pafos
# Processing Record 25 of Set 15 | molina
# Processing Record 26 of Set 15 | ambilobe
# Processing Record 27 of Set 15 | kuruman
# Processing Record 28 of Set 15 | plymouth
# Processing Record 29 of Set 15 | pokhara
# Processing Record 30 of Set 15 | bobo dioulasso
# Processing Record 31 of Set 15 | rurrenabaque
# Processing Record 32 of Set 15 | buraydah
# Processing Record 33 of Set 15 | misasi
# Processing Record 34 of Set 15 | stromness
# Processing Record 35 of Set 15 | rincon
# Processing Record 36 of Set 15 | freistadt
# Processing Record 37 of Set 15 | kralendijk
# Processing Record 38 of Set 15 | autazes
# Processing Record 39 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 15 | vallenar
# Processing Record 41 of Set 15 | shatsk
# Processing Record 42 of Set 15 | carballo
# Processing Record 43 of Set 15 | novy bydzov
# Processing Record 44 of Set 15 | tavda
# Processing Record 45 of Set 15 | gwadar
# Processing Record 46 of Set 15 | owando
# Processing Record 47 of Set 15 | vilshofen
# Processing Record 48 of Set 15 | micheweni
# Processing Record 49 of Set 15 | petrivka
# Processing Record 50 of Set 15 | farafangana
# Processing Record 1 of Set 16 | yarmouth
# Processing Record 2 of Set 16 | kinkala
# Processing Record 3 of Set 16 | sabha
# Processing Record 4 of Set 16 | ivanava
# Processing Record 5 of Set 16 | antequera
# Processing Record 6 of Set 16 | high rock
# Processing Record 7 of Set 16 | tammisaari
# Processing Record 8 of Set 16 | aden
# Processing Record 9 of Set 16 | lavumisa
# Processing Record 10 of Set 16 | lajas
# Processing Record 11 of Set 16 | thies
# Processing Record 12 of Set 16 | manta
# Processing Record 13 of Set 16 | culebra
# Processing Record 14 of Set 16 | sotouboua
# Processing Record 15 of Set 16 | gat
# Processing Record 16 of Set 16 | saint-louis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Codrington      AU -38.2667  141.9667     55.74        59          66
# 1    Itaquitinga      BR  -7.6678  -35.1017     81.61        88          25
# 2    Port Alfred      ZA -33.5906   26.8910     56.48        79           0
# 3        Kamenka      RU  51.3223   42.7678     32.05        77          12
# 4        Ushuaia      AR -54.8000  -68.3000     35.26        69          75
# ..           ...     ...      ...       ...       ...       ...         ...
# 712        Manta      EC  -0.9500  -80.7333     73.18        83          20
# 713      Culebra      PR  18.3030  -65.3010     82.20        77          58
# 714    Sotouboua      TG   8.5667    0.9833     72.66        90          35
# 715          Gat      IL  31.6100   34.7642     67.41        83          10
# 716  Saint-Louis      SN  16.3333  -15.0000     83.34        41          47
#
#      Wind Speed Current Description
# 0         11.68       broken clouds
# 1          2.62    scattered clouds
# 2         10.69           clear sky
# 3         13.80          few clouds
# 4         20.71          light snow
# ..          ...                 ...
# 712        6.91          few clouds
# 713        1.01       broken clouds
# 714        2.28    scattered clouds
# 715        3.60           clear sky
# 716        6.87    scattered clouds
#
# [717 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
